# %%
pip install folium pandas geopandas
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting folium
#   Downloading folium-0.19.4-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: pandas in c:\users\dhiraj.kumar\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\dhiraj.kumar\appdata\local\programs\python\python312\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\users\dhiraj.kumar\appdata\local\programs\python\python312\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\dhiraj.kumar\appdata\local\programs\python\python312\lib\site-packages (from folium) (2.32.3)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2025.1.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dhiraj.kumar\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dhiraj.kumar\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dhiraj.kumar\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.10.0-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging in c:\users\dhiraj.kumar\appdata\roaming\python\python312\site-packages (from geopandas) (24.1)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Downloading pyproj-3.7.0-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.0.6-cp312-cp312-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dhiraj.kumar\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: certifi in c:\users\dhiraj.kumar\appdata\local\programs\python\python312\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\dhiraj.kumar\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dhiraj.kumar\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dhiraj.kumar\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dhiraj.kumar\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (2.2.3)
# Downloading folium-0.19.4-py2.py3-none-any.whl (110 kB)
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading pyogrio-0.10.0-cp312-cp312-win_amd64.whl (16.2 MB)
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/16.2 MB 6.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.8/16.2 MB 4.0 MB/s eta 0:00:04
#    ------- -------------------------------- 3.1/16.2 MB 5.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 4.2/16.2 MB 5.0 MB/s eta 0:00:03
#    ------------- -------------------------- 5.5/16.2 MB 5.1 MB/s eta 0:00:03
#    ------------------- -------------------- 7.9/16.2 MB 6.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.5/16.2 MB 7.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.2/16.2 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.2 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 8.4 MB/s eta 0:00:00
# Downloading pyproj-3.7.0-cp312-cp312-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ---------------- ----------------------- 2.6/6.2 MB 15.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.5/6.2 MB 10.7 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 8.7 MB/s eta 0:00:00
# Downloading shapely-2.0.6-cp312-cp312-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 9.4 MB/s eta 0:00:00
# Downloading xyzservices-2025.1.0-py3-none-any.whl (88 kB)
# Installing collected packages: xyzservices, shapely, pyproj, pyogrio, branca, geopandas, folium
# Successfully installed branca-0.8.1 folium-0.19.4 geopandas-1.0.1 pyogrio-0.10.0 pyproj-3.7.0 shapely-2.0.6 xyzservices-2025.1.0
#   WARNING: The script pyproj.exe is installed in 'c:\Users\dhiraj.kumar\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Step 2: Import libraries
import folium
import pandas as pd
import json
from folium.features import CustomIcon

# %%
# Step 3: Create sample dataset with coordinates
data = {
    'State': ['Maharashtra', 'Karnataka', 'Tamil Nadu', 'Uttar Pradesh', 'Gujarat'],
    'Population': [124862220, 67562686, 77841267, 237882725, 63872399],
    'Capital': ['Mumbai', 'Bengaluru', 'Chennai', 'Lucknow', 'Gandhinagar'],
    'Capital_Lat': [19.0760, 12.9716, 13.0827, 26.8467, 23.2156],
    'Capital_Lon': [72.8777, 77.5946, 80.2707, 80.9462, 72.6369],
    'Top_Cities': [
        'Mumbai, Pune, Nashik, Nagpur',
        'Bengaluru, Mysuru, Mangaluru',
        'Chennai, Coimbatore, Madurai',
        'Lucknow, Kanpur, Agra, Varanasi',
        'Ahmedabad, Surat, Vadodara'
    ],
    'IT_City': ['Pune', 'Bengaluru', 'Chennai', 'Noida', 'Gandhinagar'],
    'IT_Lat': [18.5204, 12.9716, 13.0827, 28.5355, 23.2156],
    'IT_Lon': [73.8567, 77.5946, 80.2707, 77.3910, 72.6369]
}

df = pd.DataFrame(data)

# %%
# Step 4: Load GeoJSON file (replace with your actual path)
# Download from: https://raw.githubusercontent.com/geohacker/india/master/state/india_state.geojson
geojson_path = 'india_state.geojson'

# %%
# Step 5: Create base map
india_map = folium.Map(
    location=[20.5937, 78.9629],  # India's coordinates
    zoom_start=5,
    tiles='cartodbpositron',
    width=800,
    height=600
)

# %%
# Step 6: Add state boundaries with population data
folium.GeoJson(
    geojson_path,
    name='State Boundaries',
    style_function=lambda feature: {
        'fillColor': '#F0E442',
        'color': '#000000',
        'weight': 1,
        'fillOpacity': 0.3
    },
    tooltip=folium.features.GeoJsonTooltip(
        fields=['NAME_1'],
        aliases=['State: '],
        labels=True
    ),
    popup=folium.features.GeoJsonPopup(
        fields=['NAME_1'],
        aliases=['State: ']
    )
).add_to(india_map)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Step 6: Add state boundaries with population data
# ----> 2 folium.GeoJson(
#       3     geojson_path,
#       4     name='State Boundaries',
#       5     style_function=lambda feature: {
#       6         'fillColor': '#F0E442',
#       7         'color': '#000000',
#       8         'weight': 1,
#       9         'fillOpacity': 0.3
#      10     },
#      11     tooltip=folium.features.GeoJsonTooltip(
#      12         fields=['NAME_1'],
#      13         aliases=['State: '],
#      14         labels=True
#      15     ),
#      16     popup=folium.features.GeoJsonPopup(
#      17         fields=['NAME_1'],
#      18         aliases=['State: ']
#      19     )
#      20 ).add_to(india_map)
#
# File c:\Users\dhiraj.kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\folium\features.py:710, in GeoJson.__init__(self, data, style_function, highlight_function, popup_keep_highlighted, name, overlay, control, show, smooth_factor, tooltip, embed, popup, zoom_on_click, marker, **kwargs)
#     707 self.marker = marker
#     708 self.options = remove_empty(**kwargs)
# --> 710 self.data = self.process_data(data)
#     712 if self.style or self.highlight:
#     713     self.convert_to_feature_collection()
#
# File c:\Users\dhiraj.kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\folium\features.py:747, in GeoJson.process_data(self, data)
#     745         if not self.embed:
#     746             self.embed_link = data
# --> 747         with open(data) as f:
#     748             return json.loads(f.read())
#     749 elif hasattr(data, "__geo_interface__"):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'india_state.geojson'

# %%
# Step 7: Add Capital markers
for idx, row in df.iterrows():
    folium.Marker(
        location=[row['Capital_Lat'], row['Capital_Lon']],
        popup=f"""
        <b>{row['State']}</b><br>
        Population: {row['Population']:,}<br>
        Capital: {row['Capital']}<br>
        Top Cities: {row['Top_Cities']}
        """,
        icon=folium.Icon(color='blue', icon='star', prefix='fa'),
        tooltip=f"Capital: {row['Capital']}"
    ).add_to(india_map)

# %%
# Step 8: Add IT Hub markers with custom icons
it_icon = folium.Icon(
    color='purple',
    icon='server',
    prefix='fa',  # Font Awesome icons
    icon_color='white'
)

for idx, row in df.iterrows():
    folium.Marker(
        location=[row['IT_Lat'], row['IT_Lon']],
        popup=f"<b>IT Hub:</b> {row['IT_City']}",
        icon=it_icon,
        tooltip=f"IT Hub: {row['IT_City']}"
    ).add_to(india_map)

# %%
# Step 9: Add layer control and title
folium.LayerControl(position='topright').add_to(india_map)
title_html = '''
     <h3 align="center" style="font-size:16px"><b>Interactive Map of India</b></h3>
     <h4 align="center">States with Population, Capitals, Top Cities & IT Hubs</h4>
'''
india_map.get_root().html.add_child(folium.Element(title_html))

# %%
# Step 10: Display and save map
display(india_map)
india_map.save('india_interactive_map.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc9c098f7a0f91dafa14b46abff303a3 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#      &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Interactive Map of India&lt;/b&gt;&lt;/h3&gt;
#      &lt;h4 align=&quot;center&quot;&gt;States with Population, Capitals, Top Cities &amp; IT Hubs&lt;/h4&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc9c098f7a0f91dafa14b46abff303a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc9c098f7a0f91dafa14b46abff303a3 = L.map(
#                 &quot;map_cc9c098f7a0f91dafa14b46abff303a3&quot;,
#                 {
#                     center: [20.5937, 78.9629],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a14676e5b28cce2fdebcf6b5e15d7b1f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a14676e5b28cce2fdebcf6b5e15d7b1f.addTo(map_cc9c098f7a0f91dafa14b46abff303a3);
#
#
#             var marker_52f361e3f05fdf522944e835e2116fdd = L.marker(
#                 [19.076, 72.8777],
#                 {
# }
#             ).addTo(map_cc9c098f7a0f91dafa14b46abff303a3);
#
#
#             var icon_dd66c09207c3eac5da2e44a95b6ff41c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_52f361e3f05fdf522944e835e2116fdd.setIcon(icon_dd66c09207c3eac5da2e44a95b6ff41c);
#
#
#         var popup_202acf3e08f4bd3046b8ef54c56af806 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dae832335fff9bae18fdf89db4371bc2 = $(`&lt;div id=&quot;html_dae832335fff9bae18fdf89db4371bc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Maharashtra&lt;/b&gt;&lt;br&gt;         Population: 124,862,220&lt;br&gt;         Capital: Mumbai&lt;br&gt;         Top Cities: Mumbai, Pune, Nashik, Nagpur         &lt;/div&gt;`)[0];
#                 popup_202acf3e08f4bd3046b8ef54c56af806.setContent(html_dae832335fff9bae18fdf89db4371bc2);
#
#
#
#         marker_52f361e3f05fdf522944e835e2116fdd.bindPopup(popup_202acf3e08f4bd3046b8ef54c56af806)
#         ;
#
#
#
#
#             marker_52f361e3f05fdf522944e835e2116fdd.bindTooltip(
#                 `&lt;div&gt;
#                      Capital: Mumbai
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f854dc38b6ddbe3fd05a9da7f8a56899 = L.marker(
#                 [12.9716, 77.5946],
#                 {
# }
#             ).addTo(map_cc9c098f7a0f91dafa14b46abff303a3);
#
#
#             var icon_54efb4d30a49715d537db72499862033 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_f854dc38b6ddbe3fd05a9da7f8a56899.setIcon(icon_54efb4d30a49715d537db72499862033);
#
#
#         var popup_a440d279b93b4ac4d4176ad7af54a485 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fe1e9ed0ebf3da02c371de948ada513 = $(`&lt;div id=&quot;html_1fe1e9ed0ebf3da02c371de948ada513&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Karnataka&lt;/b&gt;&lt;br&gt;         Population: 67,562,686&lt;br&gt;         Capital: Bengaluru&lt;br&gt;         Top Cities: Bengaluru, Mysuru, Mangaluru         &lt;/div&gt;`)[0];
#                 popup_a440d279b93b4ac4d4176ad7af54a485.setContent(html_1fe1e9ed0ebf3da02c371de948ada513);
#
#
#
#         marker_f854dc38b6ddbe3fd05a9da7f8a56899.bindPopup(popup_a440d279b93b4ac4d4176ad7af54a485)
#         ;
#
#
#
#
#             marker_f854dc38b6ddbe3fd05a9da7f8a56899.bindTooltip(
#                 `&lt;div&gt;
#                      Capital: Bengaluru
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_ad0122f318d9604dbaee782e8c99a551 = L.marker(
#                 [13.0827, 80.2707],
#                 {
# }
#             ).addTo(map_cc9c098f7a0f91dafa14b46abff303a3);
#
#
#             var icon_17d3188f571eb93074b7e7a2b6932d02 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
